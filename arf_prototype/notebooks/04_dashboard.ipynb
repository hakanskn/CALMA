# %% [markdown]
# # 04 — DashboardGradio panelini başlatır. `share=True` ile public ngrok URL üretir.URL'yi tarayıcıda aç → tüm run'ları buradan yönet.

# %%
import os, syssys.path.insert(0, '/content/arf_prototype')os.environ.setdefault('DRIVE_BASE', '/content/drive/MyDrive/arf_results')

# %%
from dashboard.app import create_appapp = create_app()app.launch(    share=True,    debug=False,    server_name='0.0.0.0',    server_port=7860,)
